# %%
import pandas as pd 
import joblib
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

df = pd.read_csv('Social_Network_Ads.csv')
df
x = df.drop(['Purchased'], axis=1)
y = df['Purchased']

model = KNeighborsClassifier(n_neighbors=5)
model.fit(x,y)

prediction = model.predict([[30,87000]])
print(prediction)
plt.scatter(df['Age'],df['EstimatedSalary'], c=df['Purchased'])
plt.xlabel('Age')
plt.ylabel('EstimatedSalary')
plt.show()  
joblib.dump(model, 'knn_model.pkl')
# Out:
# [0]
# /home/ramesh/KNN/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ['knn_model.pkl']
